# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
sb.boxplot(x='age',data=df)#shows median,outliers,quartiles
# Out:
# <Axes: xlabel='age'>

# %%
sb.boxenplot(x='age',data=df)#same as box plot but gives more detailed info
# Out:
# <Axes: xlabel='age'>

# %%
sb.violinplot(x='age',data=df)#combines boxplot with its kernel density(kde)
# Out:
# <Axes: xlabel='age'>

# %%
sb.histplot(x='age',data=df)#
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sb.rugplot(x='age',data=df)#shows density
# Out:
# <Axes: xlabel='age'>

# %%
sb.kdeplot(x='age',data=df)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sb.kdeplot(x='age',data=df,shade=True)
# Out:
# C:\Users\ajink\AppData\Local\Temp\ipykernel_22348\3274907237.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(x='age',data=df,shade=True)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sb.stripplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sb.swarmplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>
# C:\Users\ajink\Anaconda\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sb.rugplot(x='age',data=df,hue='ca')
# Out:
# <Axes: xlabel='age'>

# %%
sb.boxplot(x='age',data=df,hue='ca')
# Out:
# <Axes: xlabel='age'>

# %%
sb.ecdfplot(y='thal',data=df,hue='ca')
# Out:
# <Axes: xlabel='Proportion', ylabel='thal'>

# %%
sb.kdeplot(x='age',data=df,hue='ca')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sb.rugplot(x='age',data=df,hue='ca')
# Out:
# <Axes: xlabel='age'>

# %%
sb.violinplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sb.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sb.boxenplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sb.kdeplot(x='age',data=df, shade=True)
# Out:
# C:\Users\ajink\AppData\Local\Temp\ipykernel_18004\843644896.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(x='age',data=df, shade=True)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sb.histplot(x='age',data=df)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sb.boxplot(x='age',data=df, hue='ca')
# Out:
# <Axes: xlabel='age'>

# %%
sb.kdeplot(x='age',data=df,hue='ca')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sb.boxenplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>
