# %%
import bs4

# %%
import requests

# %%
req=requests.get("https://www.flipkart.com/infinix-note-40-pro-5g-titan-gold-256-gb/p/itmabf2f4763835d?pid=MOBGZCBWJ36YUPPF&lid=LSTMOBGZCBWJ36YUPPFS5VXM6&otracker=clp_banner_1_6.bannerX3.BANNER_mobile-phones-store_83I5H44J6KEC&fm=neo%2Fmerchandising&iid=M_552d1e16-7cf8-4082-8910-de4a4907942b_6.83I5H44J6KEC&ppt=browse&ppn=browse&ssid=kzm2codgfk0000001715090343145")

# %%
req
# Out:
# <Response [200]>

# %%
soup=bs4.BeautifulSoup(req.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
review=soup.findAll('div',{'class':'ZmyHeo'})
for rev in review:
    print(rev.get_text()+ '\n')
# Out:
# Nice productREAD MORE
#
# Camera quality is not upto  the mark, rest is good in this range.READ MORE
#
# Average phone. Mag charge use over heating prblm..READ MORE
#
# Value for moneyREAD MORE
#
# Nice phone ✌️✌️✌️ good battery backupREAD MORE
#
# Amazing product feels soo premium in hand too goodREAD MORE
#
# nice product.. Not bad 👍READ MORE
#
# Good productsREAD MORE
#
# Nice product I am so happy thank you infinix thanks to Flipkart🩷🩷READ MORE
#
# Valuable product at this price range..READ MORE

# %%
rating=soup.find('div',{'class':'ipqd2A'}).get_text()

# %%
print(rating)
# Out:
# 3.8
