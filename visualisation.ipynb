# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Heart Attack Data Set.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.target.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x="target", data=df)
plt.show()

# %%
NoDisease = len(df[df.target==0])
YesDisease = len(df[df.target==1])
print("Percentage of Patients Haven't Heart Disease: {:.2f}%".format((NoDisease/(len(df.target))*100)))
print("Percentage of Patients Have Heart Disease: {:.2f}%".format((YesDisease/(len(df.target))*100)))
# Out:
# Percentage of Patients Haven't Heart Disease: 45.54%
# Percentage of Patients Have Heart Disease: 54.46%

# %%
countFemale = len(df[df.sex==0])
countMale = len(df[df.sex==1])
print("Percentage of Female Patients: {:.2f}%".format((countFemale/(len(df.sex))*100)))
print("Percentage of Male Patients: {:.2f}%".format((countMale/(len(df.sex))*100)))
# Out:
# Percentage of Female Patients: 31.68%
# Percentage of Male Patients: 68.32%

# %%
df.sex.value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(x='sex',data=df)
plt.xlabel("Sex (0=Female, 1=Male)")
plt.show()

# %%
pd.crosstab(df.age,df.target).plot(kind="bar",figsize=(20,6))
plt.title("Heart Disease Frequency for Ages")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
pd.crosstab(df.sex,df.target).plot(kind="bar",figsize=(15,6))
plt.title("Heart Disease Frequency for Sex")
plt.xlabel("Sex( (0=Female, 1=Male)")
plt.ylabel("Frequency")
plt.xticks(rotation=0)
plt.show()

# %%
pd.crosstab(df.cp,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Heart Disease Frequency According To Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %%
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)])
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Not Disease", "Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate")
plt.show()

# %%
# Plotting Histogram
plt.figure(figsize=(10, 6))
plt.hist(df['age'],color='skyblue',edgecolor='black')
plt.title('Histogram of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Assuming the dataset has a 'date' column for time series
plt.figure(figsize=(10, 6))
plt.plot(df['sex'], df['target'])
plt.title('disease over years')
plt.xlabel('Year')
plt.ylabel('disease')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
dg = pd.read_csv("dataset_Facebook.csv",sep=';')
dg
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# Assuming the dataset has a 'date' column for time series
plt.figure(figsize=(10, 6))
plt.plot(dg['Post Month'], dg['Type'])
plt.title('disease over years')
plt.xlabel('Year')
plt.ylabel('disease')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Assuming the dataset has columns for different pages or posts
plt.figure(figsize=(10, 6))
plt.plot(dg['Post Month'], dg['like'], label='Likes')
plt.plot(dg['Post Month'], dg['comment'], label='Comments')
plt.plot(dg['Post Month'], dg['share'], label='Shares')
plt.title('Likes Comparison Across Pages')
plt.xlabel('Date')
plt.ylabel('Likes')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
